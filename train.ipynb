# %%
import matplotlib.pyplot as plt
import tensorflow as tf

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv2D, Dropout, Flatten, MaxPooling2D

from sudokudetector.model import Model

# %matplotlib inline

# %%
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()

image_index = 7777 # You may select anything up to 60,000
print(y_train[image_index]) # The label is 8
plt.imshow(x_train[image_index], cmap='Greys')
# Out:
# 8

# %%
x_train.shape
# Out:
# (60000, 28, 28)

# %%
# Reshaping the array to 4-dims so that it can work with the Keras API
x_train = x_train.reshape(x_train.shape[0], 28, 28, 1)
x_test = x_test.reshape(x_test.shape[0], 28, 28, 1)
input_shape = (28, 28, 1)

plt.imshow(x_train[image_index], cmap='Greys')
print('x_train shape:', x_train.shape)
print('Number of images in x_train', x_train.shape[0])
print('Number of images in x_test', x_test.shape[0])
# Out:
# x_train shape: (60000, 28, 28, 1)
# Number of images in x_train 60000
# Number of images in x_test 10000

# %%
model = Model(input_shape)

# %%
model.train(x_train, y_train, 10)
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.2228 - accuracy: 0.9338
# Epoch 2/10
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.0882 - accuracy: 0.9728
# Epoch 3/10
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0619 - accuracy: 0.9801
# Epoch 4/10
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0477 - accuracy: 0.9846
# Epoch 5/10
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.0362 - accuracy: 0.9880
# Epoch 6/10
# 1875/1875 [==============================] - 12s 7ms/step - loss: 0.0320 - accuracy: 0.9896
# Epoch 7/10
# 1875/1875 [==============================] - 12s 7ms/step - loss: 0.0262 - accuracy: 0.9911
# Epoch 8/10
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.0211 - accuracy: 0.9924
# Epoch 9/10
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.0207 - accuracy: 0.9924
# Epoch 10/10
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0182 - accuracy: 0.9934

# %%
model.evaluate(x_test, y_test)
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0604 - accuracy: 0.9858
# [0.06040452420711517, 0.98580002784729]

# %%
image_index = 4444
plt.imshow(x_test[image_index],cmap='Greys')
pred = model.predict(x_test[image_index])
print(pred)
print(pred.argmax())
# Out:
# [[3.9993029e-22 1.0275841e-22 2.3010783e-15 6.4160331e-13 1.4475560e-08
#   2.6402422e-12 1.0080010e-22 3.3138865e-12 1.2415618e-14 1.0000000e+00]]
# 9

# %%
model.save_model('model.h5')
