# %%
from sudokudetector.image import sudoku_detect, split_cell
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib inline

ims_name = list(filter(lambda x: '.jpg' in x, os.listdir('v1_training')))
result = sudoku_detect('v1_training/image9.jpg')
cell = split_cell(result[1])

for i in range(81):
    plt.imshow(next(cell), cmap="gray")
    plt.xticks([])
    plt.yticks([])
    plt.show()
