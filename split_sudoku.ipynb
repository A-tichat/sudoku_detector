# %%
from sudokudetector.image import Sudoku
import matplotlib.pyplot as plt
import numpy as np
import os

# %matplotlib inline

# ims_name = list(filter(lambda x: '.jpg' in x, os.listdir('dataset')))
sudoku = Sudoku('dataset/image9.jpg')

# %%
plt.imshow(sudoku.cells[0, 0], cmap='gray')
