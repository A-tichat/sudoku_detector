# %%
from sudokudetector.Sudoku import Sudoku
import matplotlib.pyplot as plt
import numpy as np
import os
import cv2

# %matplotlib inline

# ims_name = list(filter(lambda x: '.jpg' in x, os.listdir('dataset')))
sudoku = Sudoku('dataset/image201.jpg')

# %%
fig=plt.figure(figsize=(9, 9))
for x in range(9):
    for y in range(9):
        fig.add_subplot(9, 9, y+(9*x) + 1)
        plt.imshow(sudoku.cells[x, y], cmap='gray')
plt.show()

# %%
fig=plt.figure(figsize=(9, 9))
for x in range(9):
    for y in range(9):
        fig.add_subplot(9, 9, y+(9*x) + 1)
        plt.imshow(sudoku.cells[x, y], cmap='gray')
plt.show()

# %%
import cv2
import imutils

fig=plt.figure(figsize=(9, 9))
for x in range(9):
    for y in range(9):
        fig.add_subplot(9, 9, y+(9*x) + 1)
        gray_cell = sudoku.cells[x, y]
        _, thresh = cv2.threshold(
                gray_cell, 0, 240, cv2.THRESH_BINARY_INV | cv2.THRESH_OTSU)
        thresh = clear_border(thresh)
        # cnts = imutils.grab_contours(thresh)
        # cnts = sorted(cnts, key=cv2.contourArea, reverse=True)
        # if len(cnts) ==0:
        #     plt.imshow(clear_border(thresh), cmap='gray')
        #     continue
        # c = max(cnts, key=cv2.contourArea)
        # mask = np.zeros(thresh.shape, dtype="uint8")
        # cv2.drawContours(mask, [c], -1, 255, -1)
        plt.imshow(thresh, cmap='gray')
plt.show()
