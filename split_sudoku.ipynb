# %%
from sudokudetector.Sudoku import Sudoku
import matplotlib.pyplot as plt
import numpy as np
import os
import cv2

# %matplotlib inline

ims_name = list(filter(lambda x: '.jpg' in x, os.listdir('dataset')))
# for iname in ims_name:
#     try:
#         Sudoku('dataset/'+iname)
#     except e:
#         print(iname)
#         print(e)

sudoku = Sudoku('dataset/image202.jpg')

# %%
fig=plt.figure(figsize=(9, 9))
for x in range(9):
    for y in range(9):
        fig.add_subplot(9, 9, y+(9*x) + 1)
        plt.imshow(sudoku.cells[x, y], cmap='gray')
plt.show()
